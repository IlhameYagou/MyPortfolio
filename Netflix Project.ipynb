# %%
#Import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#import the dataset
nfdf = pd.read_csv(r'C:\Users\Amine\Desktop\Python Projects\Netflix Project\netflixData.csv')

# %%
nfdf.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
nfdf.tail()
# Out:
#                                    Show Id                Title  \
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d            الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6         دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                 海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26              반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d  최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description           Director  \
# 5962  On his wedding day, an arrogant, greedy accoun...  Ahmed Nader Galal
# 5963  A group of women leaves Kuwait to attend unive...                NaN
# 5964  Two brothers start a new life in Singapore, wh...                NaN
# 5965  After people in his town start turning up dead...      Hong-seon Kim
# 5966  Miniforce, a special task force of elite range...      Young Jun Lee
#
#                                        Genres  \
# 5962   Comedies, Dramas, International Movies
# ...

# %%
nfdf.shape
# Out:
# (5967, 13)

# %%
nfdf.size
# Out:
# 77571

# %%
nfdf.columns
# Out:
# Index(['Show Id', 'Title', 'Description', 'Director', 'Genres', 'Cast',
#        'Production Country', 'Release Date', 'Rating', 'Duration',
#        'Imdb Score', 'Content Type', 'Date Added'],
#       dtype='object')

# %%
nfdf.dtypes
# Out:
# Show Id                object
# Title                  object
# Description            object
# Director               object
# Genres                 object
# Cast                   object
# Production Country     object
# Release Date          float64
# Rating                 object
# Duration               object
# Imdb Score             object
# Content Type           object
# Date Added             object
# dtype: object

# %%
nfdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Show Id             5967 non-null   object
#  1   Title               5967 non-null   object
#  2   Description         5967 non-null   object
#  3   Director            3903 non-null   object
#  4   Genres              5967 non-null   object
#  5   Cast                5437 non-null   object
#  6   Production Country  5408 non-null   object
#  7   Release Date        5964 non-null   float64
#  8   Rating              5963 non-null   object
#  9   Duration            5964 non-null   object
#  10  Imdb Score          5359 non-null   object
#  11  Content Type        5967 non-null   object
#  12  Date Added          4632 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 606.2+ KB

# %%
#Check for duplicates and remove them
nfdf[nfdf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Content Type, Date Added]
# Index: []

# %%
nfdf = nfdf.drop_duplicates()

# %%
nfdf.shape
# Out:
# (5967, 13)

# %%
#Check for null values
nfdf.isnull()
# Out:
#       Show Id  Title  Description  Director  Genres   Cast  \
# 0       False  False        False      True   False   True
# 1       False  False        False     False   False  False
# 2       False  False        False     False   False  False
# 3       False  False        False      True   False  False
# 4       False  False        False     False   False   True
# ...       ...    ...          ...       ...     ...    ...
# 5962    False  False        False     False   False  False
# 5963    False  False        False      True   False  False
# 5964    False  False        False      True   False  False
# 5965    False  False        False     False   False  False
# 5966    False  False        False     False   False  False
#
#       Production Country  Release Date  Rating  Duration  Imdb Score  \
# 0                  False         False   False     False       False
# 1                  False         False   False     False       False
# ...

# %%
nfdf.isnull().sum()
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %%
#Use the heatmap to show the null values
sns.heatmap(nfdf.isnull())
# Out:
# <Axes: >

# %%
#Question1 = What is the show id and who is the director of '13 Reasons Why'

# %%
nfdf.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
nfdf[nfdf['Title'].isin(['13 Reasons Why'])]
# Out:
#                                  Show Id           Title  \
# 20  ee4f5117-cf68-4862-b61c-310fb8c7379b  13 Reasons Why
#
#                                           Description Director  \
# 20  After a teenage girl's perplexing suicide, a c...      NaN
#
#                                      Genres  \
# 20  Crime TV Shows, TV Dramas, TV Mysteries
#
#                                                  Cast Production Country  \
# 20  Dylan Minnette, Katherine Langford, Kate Walsh...      United States
#
#     Release Date Rating   Duration Imdb Score Content Type    Date Added
# 20        2020.0  TV-MA  4 Seasons     7.5/10      TV Show  June 5, 2020

# %%
#Second Method using str.contains
nfdf[nfdf['Title'].str.contains('13 Reasons Why')]
# Out:
#                                  Show Id                               Title  \
# 20  ee4f5117-cf68-4862-b61c-310fb8c7379b                      13 Reasons Why
# 21  eda9ad19-b8d7-40dd-b3d2-4ff997387d53  13 Reasons Why: Beyond the Reasons
#
#                                           Description Director  \
# 20  After a teenage girl's perplexing suicide, a c...      NaN
# 21  Cast members, writers, producers and mental he...      NaN
#
#                                      Genres  \
# 20  Crime TV Shows, TV Dramas, TV Mysteries
# 21               Crime TV Shows, Docuseries
#
#                                                  Cast Production Country  \
# 20  Dylan Minnette, Katherine Langford, Kate Walsh...      United States
# 21  Dylan Minnette, Katherine Langford, Kate Walsh...      United States
#
#     Release Date Rating   Duration Imdb Score Content Type       Date Added
# 20        2020.0  TV-MA  4 Seasons     7.5/10      TV Show     June 5, 2020
# ...

# %%
#Question2: What is the year in which the highest number of TV shows and movies were released?

# %%
#First, convert the release date column into datetime data type
nfdf['Date'] = pd.to_datetime(nfdf['Date Added'])

# %%
nfdf.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
nfdf.dtypes
# Out:
# Show Id                       object
# Title                         object
# Description                   object
# Director                      object
# Genres                        object
# Cast                          object
# Production Country            object
# Release Date                 float64
# Rating                        object
# Duration                      object
# Imdb Score                    object
# Content Type                  object
# Date Added                    object
# Date                  datetime64[ns]
# dtype: object

# %%
nfdf['Date'].dt.year.value_counts()
# Out:
# Date
# 2020.0    1307
# 2021.0     942
# 2019.0     891
# 2018.0     784
# 2017.0     457
# 2016.0     174
# 2015.0      39
# 2014.0      16
# 2011.0      13
# 2013.0       5
# 2009.0       2
# 2012.0       1
# 2008.0       1
# Name: count, dtype: int64

# %%
nfdf['Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
#Question3: What is the total number of TV shows in this dataset?

# %%
nfdf = pd.read_csv(r'C:\Users\Amine\Desktop\Python Projects\Netflix Project\netflixData.csv')

# %%
nfdf.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
nfdf = nfdf.rename(columns = {'Content Type':'Category'})

# %%
nfdf.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
nfdf.groupby('Category').Category.count()
# Out:
# Category
# Movie      3867
# TV Show    2100
# Name: Category, dtype: int64

# %%
sns.countplot(nfdf['Category'])
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
#Question4: Show all the movies that were released in year 2000

# %%
nfdf['Date'] = pd.to_datetime(nfdf['Date Added'])

# %%
#first, we create a new column called Year
nfdf['Year'] = nfdf['Date'].dt.year

# %%
nfdf.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
#Now, we have to find the movies that were released in 2000
nfdf[(nfdf['Category'] == 'Movie') & (nfdf['Year'] == 2000)]
#This means that no movies were released in the year 2000
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Category, Date Added, Date, Year]
# Index: []

# %%
#Question5: Show the top 10 directors who sold the highest numbers of TV shows and movies to Netflix

# %%
nfdf['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               15
# Jay Karas                 14
# Youssef Chahine           12
# Cathy Garcia-Molina       12
# Jay Chapman               11
# Lance Bangs                8
# Don Michael Paul           8
# Fernando Ayllón            8
# Name: count, dtype: int64

# %%
#Question6: Show all the records where Category is Movie and Type is Comedies

# %%
nfdf[(nfdf['Category'] == 'Movie') & (nfdf['Genres'] == 'Comedies')]
# Out:
#                                    Show Id  \
# 7     c844460f-6178-4f87-929e-80816c74ca35
# 106   cf823b12-e12c-430a-ad76-eb952d4fdf88
# 191   0a413f92-95de-4789-85fa-8c7b0b0e20db
# 331   c8de84f3-2e3a-4c6f-9bb2-56d71920a189
# 456   f9ce1ae6-b7ff-405c-b71e-ac91d203a49c
# ...                                    ...
# 5574  c9401724-b1fa-4c3f-97b9-6b4e96886d89
# 5594  66954064-4137-4c85-ab98-ef00dab5b675
# 5837  d8363ccc-87e8-462c-bcd9-ff2f9daef199
# 5845  a881541f-fddc-48e3-8059-3d16ae28a719
# 5868  45761b40-bb05-4faf-bef2-276592fc274d
#
#                                                   Title  \
# 7                                          #realityhigh
# 106                         A Futile and Stupid Gesture
# 191                                            Accepted
# 331                        American Pie 9: Girls' Rules
# 456         Austin Powers: International Man of Mystery
# ...                                                 ...
# ...

# %%
#Question7: In how many movies was Leonardo Dicaprio part of the cast?

# %%
nfdf[nfdf['Cast'] == 'Leonardo Dicaprio']
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Category, Date Added, Date, Year]
# Index: []

# %%
#Question8: Drop all the null values

# %%
new_nfdf = nfdf.dropna()

# %%
new_nfdf.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
new_nfdf[new_nfdf['Cast'].str.contains('Leonardo Dicaprio')]
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Category, Date Added, Date, Year]
# Index: []

# %%
#Question9: How many movies were produced in France after 2018?

# %%
nfdf[(nfdf['Category'] == 'Movies') & (nfdf['Production Country'] == 'France') & (nfdf['Year'] > 2018)]
#This means that none of the movies meets the criterea selected
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Category, Date Added, Date, Year]
# Index: []
